# %%
msg = "hello, world!"
print(msg)
# Out:
# hello, world!

# %%
print(msg)asdf
# Out:
#   Cell In[6], line 1
#     print(msg)asdf
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# this is a mark down cell
