# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
thislist = ["apple", "banana", "cherry", "Chris"]
for x in thislist:
  print(x)
# Out:
# apple
# banana
# cherry
# Chris

# %%
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)):
    print(thislist[i])
    print(i)
# Out:
# apple
# 0
# banana
# 1
# cherry
# 2

# %%
range(len(thislist))
# Out:
# range(0, 3)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

# %%
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
thisdict.values()
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
type(thislist)
# Out:
# list

# %%
import pandas as pd

# %%
df = pd.read_excel("Azenta_NGS_PlasmidEZ_SampleUpload_Form.xlsx")

# %%
df
# Out:
#         Plate Well (V)  Sample # Sample Name* Sample Buffer*  \
# 0    plate 01       A1       1.0       HM14-1          Water
# 1    plate 01       B1       2.0       HM14-2          Water
# 2    plate 01       C1       3.0       HM14-3          Water
# 3    plate 01       D1       4.0       HM17-1          Water
# 4    plate 01       E1       5.0       HM17-2          Water
# ..        ...      ...       ...          ...            ...
# 571       NaN      D12       NaN          NaN            NaN
# 572       NaN      E12       NaN          NaN            NaN
# 573       NaN      F12       NaN          NaN            NaN
# 574       NaN      G12       NaN          NaN            NaN
# 575       NaN      H12       NaN          NaN            NaN
#
#     Method of DNA Measurement*  DNA Concentration (ng/uL)*  \
# 0                     NanoDrop                        50.0
# 1                     NanoDrop                        50.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Plate                       510 non-null    object
#  1   Well (V)                    576 non-null    object
#  2   Sample #                    500 non-null    float64
#  3   Sample Name*                6 non-null      object
#  4   Sample Buffer*              8 non-null      object
#  5   Method of DNA Measurement*  8 non-null      object
#  6   DNA Concentration (ng/uL)*  8 non-null      float64
#  7   Sample Volume (uL)*         8 non-null      float64
#  8   Total DNA Amount (ng)*      8 non-null      float64
#  9   Reference Sequence          0 non-null      float64
#  10  Host                        0 non-null      float64
#  11  Plasmid Size                8 non-null      float64
#  12  Copy Number                 0 non-null      float64
# ...

# %%
df.describe()
# Out:
#          Sample #  DNA Concentration (ng/uL)*  Sample Volume (uL)*  \
# count  500.000000                         8.0                  8.0
# mean   250.500000                        50.0                 10.0
# std    144.481833                         0.0                  0.0
# min      1.000000                        50.0                 10.0
# 25%    125.750000                        50.0                 10.0
# 50%    250.500000                        50.0                 10.0
# 75%    375.250000                        50.0                 10.0
# max    500.000000                        50.0                 10.0
#
#        Total DNA Amount (ng)*  Reference Sequence  Host  Plasmid Size  \
# count                     8.0                 0.0   0.0           8.0
# mean                    500.0                 NaN   NaN        7510.0
# std                       0.0                 NaN   NaN           0.0
# min                     500.0                 NaN   NaN        7510.0
# ...

# %%
df["Plasmid Size"].value_counts()
# Out:
# Plasmid Size
# 7510.0    8
# Name: count, dtype: int64
